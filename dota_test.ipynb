# %%
from __future__ import print_function

import argparse
import pickle
import time

import numpy as np
import os
import torch
import torch.backends.cudnn as cudnn
import torch.nn.init as init
import torch.optim as optim
import torch.utils.data as data
from torch.autograd import Variable
#os.environ["CUDA_VISIBLE_DEVICES"] = "1" #设置GPU1可见
from data import VOCroot, COCOroot, VOC_300, VOC_512, COCO_300, COCO_512, COCO_mobile_300, AnnotationTransform, \
    COCODetection, VOCDetection, detection_collate, BaseTransform, preproc,DOTA_500, DOTAroot, DOTADetection, DOTA_CLASSES
from layers.functions import Detect, PriorBox
from layers.modules import MultiBoxLoss
from utils.nms_wrapper import nms
from utils.timer import Timer

def str2bool(v):
    return v.lower() in ("yes", "true", "t", "1")

"""
parser = argparse.ArgumentParser(
    description='Receptive Field Block Net Training')
parser.add_argument('-v', '--version', default='RFB_vgg',
                    help='RFB_vgg ,RFB_E_vgg RFB_mobile SSD_vgg version.')
parser.add_argument('-s', '--size', default='300',
                    help='300 or 512 input size.')
parser.add_argument('-d', '--dataset', default='DOTA',
                    help='VOC or COCO dataset')
parser.add_argument(
    '--basenet', default='weights/vgg16_reducedfc.pth', help='pretrained base model')
parser.add_argument('--jaccard_threshold', default=0.5,
                    type=float, help='Min Jaccard index for matching')
parser.add_argument('-b', '--batch_size', default=64,
                    type=int, help='Batch size for training')
parser.add_argument('--num_workers', default=4,
                    type=int, help='Number of workers used in dataloading')
parser.add_argument('--cuda', default=True,
                    type=bool, help='Use cuda to train model')
parser.add_argument('--ngpu', default=2, type=int, help='gpus')
parser.add_argument('--lr', '--learning-rate',
                    default=4e-3, type=float, help='initial learning rate')
parser.add_argument('--momentum', default=0.9, type=float, help='momentum')

parser.add_argument('--resume_net', default=False, help='resume net for retraining')
parser.add_argument('--resume_epoch', default=0,
                    type=int, help='resume iter for retraining')
# resume_time
parser.add_argument('--resume_time', default='2019-05-20-21:48',
                    type=str, help='resume time for retraining')

parser.add_argument('-max', '--max_epoch', default=400,
                    type=int, help='max epoch for retraining')
parser.add_argument('--weight_decay', default=5e-4,
                    type=float, help='Weight decay for SGD')
parser.add_argument('-we', '--warm_epoch', default=10,
                    type=int, help='max epoch for retraining')
parser.add_argument('--gamma', default=0.1,
                    type=float, help='Gamma update for SGD')
parser.add_argument('--log_iters', default=True,
                    type=bool, help='Print the loss at each iteration')
#parser.add_argument('--save_folder', default='/home/buaab622/project/PytorchSSD-dota/weights/DOTAweights',help='Location to save checkpoint models')
parser.add_argument('--date', default='1213')
parser.add_argument('--save_frequency', default=20)
parser.add_argument('--retest', default=False, type=bool,
                    help='test cache results')
parser.add_argument('--test_frequency', default=20)
parser.add_argument('--visdom', default=False, type=str2bool, help='Use visdom to for loss visualization')
parser.add_argument('--send_images_to_visdom', type=str2bool, default=False,
                    help='Sample a random image from each 10th batch, send it to visdom after augmentations step')
                    
# test or train
parser.add_argument('--test_mode', default=False, type=bool, help='switch to test_mode')
args = parser.parse_args()
"""

# load the weight file over and over again
def loading_weights(net, root_dir, epoch_num):   
    weight_path = os.path.join(save_folder, 'RFB_vgg_DOTA'+'_epoches_' + str(epoch_num) + '.pth')
    
    print('Loading saved weight file into network', weight_path)
    state_dict = torch.load(weight_path)
    # create new OrderedDict that does not contain `module.`
    from collections import OrderedDict
    new_state_dict = OrderedDict()
    for k, v in state_dict.items():
        head = k[:7]
        if head == 'module.':
            name = k[7:]  # remove `module.`
        else:
            name = k
        new_state_dict[name] = v
    net.load_state_dict(new_state_dict)

# test net
def test_net(save_folder, net, detector, cuda, testset, transform, max_per_image=300, thresh=0.005):
    if not os.path.exists(save_folder):
        os.mkdir(save_folder)
    # dump predictions and assoc. ground truth to text file for now
    num_images = len(testset)
    num_classes = len(DOTA_CLASSES)
    all_boxes = [[[] for _ in range(num_images)]
                 for _ in range(num_classes)]

    _t = {'im_detect': Timer(), 'misc': Timer()}
    det_file = os.path.join(save_folder, 'detections.pkl')

    for i in range(num_images):
        img = testset.pull_image(i)
        x = Variable(transform(img).unsqueeze(0), volatile=True)
        if cuda:
            x = x.cuda()

        _t['im_detect'].tic()
        out = net(x=x, test=True)  # forward pass
        boxes, scores = detector.forward(out, priors)
        detect_time = _t['im_detect'].toc()
        boxes = boxes[0]
        scores = scores[0]

        boxes = boxes.cpu().numpy()
        scores = scores.cpu().numpy()
        # scale each detection back up to the image
        scale = torch.Tensor([img.shape[1], img.shape[0],
                              img.shape[1], img.shape[0]]).cpu().numpy()
        boxes *= scale

        _t['misc'].tic()

        for j in range(1, num_classes):
            inds = np.where(scores[:, j] > thresh)[0]
            if len(inds) == 0:
                all_boxes[j][i] = np.empty([0, 5], dtype=np.float32)
                continue
            c_bboxes = boxes[inds]
            c_scores = scores[inds, j]
            c_dets = np.hstack((c_bboxes, c_scores[:, np.newaxis])).astype(
                np.float32, copy=False)
            cpu = False

            keep = nms(c_dets, 0.45, force_cpu=cpu)
            keep = keep[:50]
            c_dets = c_dets[keep, :]
            all_boxes[j][i] = c_dets
        if max_per_image > 0:
            image_scores = np.hstack([all_boxes[j][i][:, -1] for j in range(1, num_classes)])
            if len(image_scores) > max_per_image:
                image_thresh = np.sort(image_scores)[-max_per_image]
                for j in range(1, num_classes):
                    keep = np.where(all_boxes[j][i][:, -1] >= image_thresh)[0]
                    all_boxes[j][i] = all_boxes[j][i][keep, :]

        nms_time = _t['misc'].toc()

        if i % 200 == 0:
            print('im_detect: {:d}/{:d} {:.3f}s {:.3f}s'
                  .format(i + 1, num_images, detect_time, nms_time))
            _t['im_detect'].clear()
            _t['misc'].clear()

    with open(det_file, 'wb') as f:
        pickle.dump(all_boxes, f, pickle.HIGHEST_PROTOCOL)

    print('Evaluating detections')
    APs, mAP = testset.evaluate_detections(all_boxes, save_folder)
    return APs, mAP

# run test
def test():
    net.eval()
    top_k = 300
    APs, mAP = test_net(test_save_dir, net, detector, cuda, testset,
                        BaseTransform(img_dim, rgb_means, rgb_std, (2, 0, 1)),
                        top_k, thresh=0.01)
    APs = [str(num) for num in APs]
    mAP = str(mAP)
    print('mAP = ',mAP)
    
if __name__ == '__main__':
    # set dataset(val or test, not train)
    train_sets = 'subset_field_500_GSC' # A subset of DOTA for training
    train_list = 'field_train' # dataset type
    val_sets = 'subset_field_500_val_GSC' # A subset of DOTA for testing
    val_list = 'field_val' # dataset type
    cfg = DOTA_500


    save_root = '/home/buaab622/project/PytorchSSD-dota/weights/DOTAweights/RFB_vgg_DOTA_300'
    save_time = '2019-06-11-03:11'
    save_folder = os.path.join(save_root, save_time)


    test_save_dir = os.path.join(save_folder, 'ss_predict')
    if not os.path.exists(test_save_dir):
        os.makedirs(test_save_dir)

    # Build net
    from models.RFB_Net_vgg import build_net

    # Some Image Parameters
    rgb_std = (1, 1, 1)
    img_dim = 300
    rgb_means = (104, 117, 123)
    p = 0.6

    # num_classes
    num_classes = len(DOTA_CLASSES)

    # Some Hyper-Parameters
    cuda = True
    ngpu = 2
    batch_size = 64
    weight_decay = 0.0005
    gamma = 0.1
    momentum = 0.9
    #net = build_net(img_dim, num_classes)
    #print(net)
    
    # dataset
    # DOTA
    print('Loading Dataset...')

    testset = DOTADetection(DOTAroot, 
                            val_sets, 
                            None, 
                            AnnotationTransform(),
                            dataset_name = val_list)
    train_dataset = DOTADetection(DOTAroot,
                                  train_sets,
                                  preproc(img_dim, rgb_means, rgb_std, p), 
                                  AnnotationTransform(), 
                                  dataset_name = train_list)
    detector = Detect(num_classes, 0, cfg)

    #optimizer = optim.SGD(net.parameters(), lr=args.lr,momentum=args.momentum, weight_decay=args.weight_decay)
    # optimizer = optim.RMSprop(net.parameters(), lr=args.lr,alpha = 0.9, eps=1e-08,
    #                      momentum=args.momentum, weight_decay=args.weight_decay)
    criterion = MultiBoxLoss(num_classes, 0.5, True, 0, True, 3, 0.5, False)
    priorbox = PriorBox(cfg)
    priors = Variable(priorbox.forward(), volatile=True)

    # load saved weight
    # resume_net_path:权重文件的路径

    """resume_epoch = 300
    resume_net_path = os.path.join(save_folder, 'RFB_vgg_DOTA'+'_epoches_' + str(resume_epoch) + '.pth')

    print('Loading resume network', resume_net_path)
    state_dict = torch.load(resume_net_path)
    # create new OrderedDict that does not contain `module.`
    from collections import OrderedDict

    new_state_dict = OrderedDict()
    for k, v in state_dict.items():
        head = k[:7]
        if head == 'module.':
            name = k[7:]  # remove `module.`
        else:
            name = k
        new_state_dict[name] = v
    net.load_state_dict(new_state_dict)"""
    epoch_num = 300
    root_dir = save_folder
    for i in range(20,410,20):
        net = build_net(img_dim, num_classes)
        epoch_num = i
        loading_weights(net, root_dir, epoch_num)
        # Build utils for training
        if ngpu > 1:
            net = torch.nn.DataParallel(net, device_ids=list(range(ngpu)))

        if cuda:
            net.cuda()
            cudnn.benchmark = True

        test()
# Out:
# Loading Dataset...
# Loading resume network /home/buaab622/project/PytorchSSD-dota/weights/DOTAweights/RFB_vgg_DOTA_300/2019-06-11-03:11/RFB_vgg_DOTA_epoches_20.pth
# im_detect: 1/1863 0.011s 0.004s
# /home/buaab622/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:245: UserWarning: volatile was removed and now has no effect. Use `with torch.no_grad():` instead.
# /home/buaab622/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:115: UserWarning: volatile was removed and now has no effect. Use `with torch.no_grad():` instead.
# im_detect: 201/1863 0.010s 0.004s
# im_detect: 401/1863 0.010s 0.003s
# im_detect: 601/1863 0.010s 0.004s
# im_detect: 801/1863 0.010s 0.003s
# im_detect: 1001/1863 0.010s 0.003s
# im_detect: 1201/1863 0.010s 0.003s
# im_detect: 1401/1863 0.010s 0.003s
# im_detect: 1601/1863 0.010s 0.004s
# im_detect: 1801/1863 0.010s 0.003s
# Evaluating detections
# Writing harbor VOC results file
# Writing soccer-ball-field VOC results file
# Writing basketball-court VOC results file
# VOC07 metric? Yes
# AP for harbor = 0.6865
# AP for soccer-ball-field = 0.4666
# AP for basketball-court = 0.6633
# Mean AP = 0.6055
# ~~~~~~~~
# Results:
# 0.686
# 0.467
# 0.663
# 0.605
# ~~~~~~~~
#
# --------------------------------------------------------------
# Results computed with the **unofficial** Python eval code.
# Results should be very close to the official MATLAB eval code.
# Recompute with `./tools/reval.py --matlab ...` for your paper.
# -- Thanks, The Management
# --------------------------------------------------------------
# mAP =  0.6054592819752381
# Loading resume network /home/buaab622/project/PytorchSSD-dota/weights/DOTAweights/RFB_vgg_DOTA_300/2019-06-11-03:11/RFB_vgg_DOTA_epoches_40.pth
# im_detect: 1/1863 0.010s 0.001s
# im_detect: 201/1863 0.010s 0.001s
# im_detect: 401/1863 0.009s 0.001s
# im_detect: 601/1863 0.010s 0.001s
# im_detect: 801/1863 0.009s 0.001s
# im_detect: 1001/1863 0.010s 0.001s
# im_detect: 1201/1863 0.010s 0.001s
# im_detect: 1401/1863 0.010s 0.001s
# im_detect: 1601/1863 0.010s 0.001s
# im_detect: 1801/1863 0.010s 0.001s
# Evaluating detections
# Writing harbor VOC results file
# Writing soccer-ball-field VOC results file
# Writing basketball-court VOC results file
# VOC07 metric? Yes
# AP for harbor = 0.7114
# AP for soccer-ball-field = 0.5803
# AP for basketball-court = 0.7161
# Mean AP = 0.6693
# ~~~~~~~~
# Results:
# 0.711
# 0.580
# 0.716
# 0.669
# ~~~~~~~~
#
# --------------------------------------------------------------
# Results computed with the **unofficial** Python eval code.
# Results should be very close to the official MATLAB eval code.
# Recompute with `./tools/reval.py --matlab ...` for your paper.
# -- Thanks, The Management
# --------------------------------------------------------------
# mAP =  0.6692806716270324
# Loading resume network /home/buaab622/project/PytorchSSD-dota/weights/DOTAweights/RFB_vgg_DOTA_300/2019-06-11-03:11/RFB_vgg_DOTA_epoches_60.pth
# im_detect: 1/1863 0.010s 0.001s
# im_detect: 201/1863 0.010s 0.001s
# im_detect: 401/1863 0.009s 0.001s
# im_detect: 601/1863 0.009s 0.001s
# im_detect: 801/1863 0.010s 0.001s
# im_detect: 1001/1863 0.009s 0.001s
# im_detect: 1201/1863 0.009s 0.001s
# im_detect: 1401/1863 0.009s 0.001s
# im_detect: 1601/1863 0.010s 0.001s
# im_detect: 1801/1863 0.009s 0.001s
# Evaluating detections
# Writing harbor VOC results file
# Writing soccer-ball-field VOC results file
# Writing basketball-court VOC results file
# VOC07 metric? Yes
# AP for harbor = 0.7406
# AP for soccer-ball-field = 0.5931
# AP for basketball-court = 0.7536
# Mean AP = 0.6958
# ~~~~~~~~
# Results:
# 0.741
# 0.593
# 0.754
# 0.696
# ~~~~~~~~
#
# --------------------------------------------------------------
# Results computed with the **unofficial** Python eval code.
# Results should be very close to the official MATLAB eval code.
# Recompute with `./tools/reval.py --matlab ...` for your paper.
# -- Thanks, The Management
# --------------------------------------------------------------
# mAP =  0.6957698576053751
# Loading resume network /home/buaab622/project/PytorchSSD-dota/weights/DOTAweights/RFB_vgg_DOTA_300/2019-06-11-03:11/RFB_vgg_DOTA_epoches_80.pth
# im_detect: 1/1863 0.010s 0.000s
# im_detect: 201/1863 0.010s 0.000s
# im_detect: 401/1863 0.009s 0.000s
# im_detect: 601/1863 0.010s 0.000s
# im_detect: 801/1863 0.009s 0.000s
# im_detect: 1001/1863 0.010s 0.000s
# im_detect: 1201/1863 0.009s 0.000s
# im_detect: 1401/1863 0.010s 0.000s
# im_detect: 1601/1863 0.009s 0.000s
# im_detect: 1801/1863 0.009s 0.000s
# Evaluating detections
# Writing harbor VOC results file
# Writing soccer-ball-field VOC results file
# Writing basketball-court VOC results file
# VOC07 metric? Yes
# AP for harbor = 0.7467
# AP for soccer-ball-field = 0.5664
# AP for basketball-court = 0.7208
# Mean AP = 0.6780
# ~~~~~~~~
# Results:
# 0.747
# 0.566
# 0.721
# 0.678
# ~~~~~~~~
#
# --------------------------------------------------------------
# Results computed with the **unofficial** Python eval code.
# Results should be very close to the official MATLAB eval code.
# Recompute with `./tools/reval.py --matlab ...` for your paper.
# -- Thanks, The Management
# --------------------------------------------------------------
# mAP =  0.6779789403556419
# Loading resume network /home/buaab622/project/PytorchSSD-dota/weights/DOTAweights/RFB_vgg_DOTA_300/2019-06-11-03:11/RFB_vgg_DOTA_epoches_100.pth
# im_detect: 1/1863 0.010s 0.000s
# im_detect: 201/1863 0.009s 0.001s
# im_detect: 401/1863 0.010s 0.000s
# im_detect: 601/1863 0.009s 0.000s
# im_detect: 801/1863 0.009s 0.000s
# im_detect: 1001/1863 0.009s 0.000s
# im_detect: 1201/1863 0.010s 0.000s
# im_detect: 1401/1863 0.009s 0.000s
# im_detect: 1601/1863 0.009s 0.000s
# im_detect: 1801/1863 0.009s 0.000s
# Evaluating detections
# Writing harbor VOC results file
# Writing soccer-ball-field VOC results file
# Writing basketball-court VOC results file
# VOC07 metric? Yes
# AP for harbor = 0.7668
# AP for soccer-ball-field = 0.5790
# AP for basketball-court = 0.7133
# Mean AP = 0.6863
# ~~~~~~~~
# Results:
# 0.767
# 0.579
# 0.713
# 0.686
# ~~~~~~~~
#
# --------------------------------------------------------------
# Results computed with the **unofficial** Python eval code.
# Results should be very close to the official MATLAB eval code.
# Recompute with `./tools/reval.py --matlab ...` for your paper.
# -- Thanks, The Management
# --------------------------------------------------------------
# mAP =  0.6863444079281563
# Loading resume network /home/buaab622/project/PytorchSSD-dota/weights/DOTAweights/RFB_vgg_DOTA_300/2019-06-11-03:11/RFB_vgg_DOTA_epoches_120.pth
# im_detect: 1/1863 0.010s 0.000s
# im_detect: 201/1863 0.010s 0.000s
# im_detect: 401/1863 0.009s 0.000s
# im_detect: 601/1863 0.009s 0.000s
# im_detect: 801/1863 0.009s 0.000s
# im_detect: 1001/1863 0.010s 0.000s
# im_detect: 1201/1863 0.010s 0.000s
# im_detect: 1401/1863 0.010s 0.000s
# im_detect: 1601/1863 0.010s 0.000s
# im_detect: 1801/1863 0.010s 0.000s
# Evaluating detections
# Writing harbor VOC results file
# Writing soccer-ball-field VOC results file
# Writing basketball-court VOC results file
# VOC07 metric? Yes
# AP for harbor = 0.7754
# AP for soccer-ball-field = 0.5981
# AP for basketball-court = 0.7256
# Mean AP = 0.6997
# ~~~~~~~~
# Results:
# 0.775
# 0.598
# 0.726
# 0.700
# ~~~~~~~~
#
# --------------------------------------------------------------
# Results computed with the **unofficial** Python eval code.
# Results should be very close to the official MATLAB eval code.
# Recompute with `./tools/reval.py --matlab ...` for your paper.
# -- Thanks, The Management
# --------------------------------------------------------------
# mAP =  0.6996919760838184
# Loading resume network /home/buaab622/project/PytorchSSD-dota/weights/DOTAweights/RFB_vgg_DOTA_300/2019-06-11-03:11/RFB_vgg_DOTA_epoches_140.pth
# im_detect: 1/1863 0.010s 0.000s
# im_detect: 201/1863 0.010s 0.000s
# im_detect: 401/1863 0.009s 0.000s
# im_detect: 601/1863 0.009s 0.000s
# im_detect: 801/1863 0.009s 0.000s
# im_detect: 1001/1863 0.010s 0.000s
# im_detect: 1201/1863 0.009s 0.000s
# im_detect: 1401/1863 0.009s 0.000s
# im_detect: 1601/1863 0.009s 0.000s
# im_detect: 1801/1863 0.010s 0.000s
# Evaluating detections
# Writing harbor VOC results file
# Writing soccer-ball-field VOC results file
# Writing basketball-court VOC results file
# VOC07 metric? Yes
# AP for harbor = 0.7812
# AP for soccer-ball-field = 0.6028
# AP for basketball-court = 0.7346
# Mean AP = 0.7062
# ~~~~~~~~
# Results:
# 0.781
# 0.603
# 0.735
# 0.706
# ~~~~~~~~
#
# --------------------------------------------------------------
# Results computed with the **unofficial** Python eval code.
# Results should be very close to the official MATLAB eval code.
# Recompute with `./tools/reval.py --matlab ...` for your paper.
# -- Thanks, The Management
# --------------------------------------------------------------
# mAP =  0.7062135082413525
# Loading resume network /home/buaab622/project/PytorchSSD-dota/weights/DOTAweights/RFB_vgg_DOTA_300/2019-06-11-03:11/RFB_vgg_DOTA_epoches_160.pth
# im_detect: 1/1863 0.010s 0.000s
# im_detect: 201/1863 0.009s 0.000s
# im_detect: 401/1863 0.009s 0.000s
# im_detect: 601/1863 0.010s 0.000s
# im_detect: 801/1863 0.009s 0.000s
# im_detect: 1001/1863 0.009s 0.000s
# im_detect: 1201/1863 0.009s 0.000s
# im_detect: 1401/1863 0.010s 0.000s
# im_detect: 1601/1863 0.009s 0.000s
# im_detect: 1801/1863 0.009s 0.000s
# Evaluating detections
# Writing harbor VOC results file
# Writing soccer-ball-field VOC results file
# Writing basketball-court VOC results file
# VOC07 metric? Yes
# AP for harbor = 0.7788
# AP for soccer-ball-field = 0.6151
# AP for basketball-court = 0.7209
# Mean AP = 0.7049
# ~~~~~~~~
# Results:
# 0.779
# 0.615
# 0.721
# 0.705
# ~~~~~~~~
#
# --------------------------------------------------------------
# Results computed with the **unofficial** Python eval code.
# Results should be very close to the official MATLAB eval code.
# Recompute with `./tools/reval.py --matlab ...` for your paper.
# -- Thanks, The Management
# --------------------------------------------------------------
# mAP =  0.704920939360298
# Loading resume network /home/buaab622/project/PytorchSSD-dota/weights/DOTAweights/RFB_vgg_DOTA_300/2019-06-11-03:11/RFB_vgg_DOTA_epoches_180.pth
# im_detect: 1/1863 0.010s 0.000s
# im_detect: 201/1863 0.009s 0.000s
# im_detect: 401/1863 0.010s 0.000s
# im_detect: 601/1863 0.009s 0.000s
# im_detect: 801/1863 0.009s 0.000s
# im_detect: 1001/1863 0.009s 0.000s
# im_detect: 1201/1863 0.010s 0.000s
# im_detect: 1401/1863 0.009s 0.000s
# im_detect: 1601/1863 0.009s 0.000s
# im_detect: 1801/1863 0.010s 0.000s
# Evaluating detections
# Writing harbor VOC results file
# Writing soccer-ball-field VOC results file
# Writing basketball-court VOC results file
# VOC07 metric? Yes
# AP for harbor = 0.7801
# AP for soccer-ball-field = 0.6086
# AP for basketball-court = 0.7280
# Mean AP = 0.7056
# ~~~~~~~~
# Results:
# 0.780
# 0.609
# 0.728
# 0.706
# ~~~~~~~~
#
# --------------------------------------------------------------
# Results computed with the **unofficial** Python eval code.
# Results should be very close to the official MATLAB eval code.
# Recompute with `./tools/reval.py --matlab ...` for your paper.
# -- Thanks, The Management
# --------------------------------------------------------------
# mAP =  0.7055754208846473
# Loading resume network /home/buaab622/project/PytorchSSD-dota/weights/DOTAweights/RFB_vgg_DOTA_300/2019-06-11-03:11/RFB_vgg_DOTA_epoches_200.pth
# im_detect: 1/1863 0.010s 0.000s
# im_detect: 201/1863 0.009s 0.000s
# im_detect: 401/1863 0.009s 0.000s
# im_detect: 601/1863 0.010s 0.000s
# im_detect: 801/1863 0.009s 0.000s
# im_detect: 1001/1863 0.009s 0.000s
# im_detect: 1201/1863 0.009s 0.000s
# im_detect: 1401/1863 0.010s 0.000s
# im_detect: 1601/1863 0.009s 0.000s
# im_detect: 1801/1863 0.009s 0.000s
# Evaluating detections
# Writing harbor VOC results file
# Writing soccer-ball-field VOC results file
# Writing basketball-court VOC results file
# VOC07 metric? Yes
# AP for harbor = 0.7796
# AP for soccer-ball-field = 0.6039
# AP for basketball-court = 0.7321
# Mean AP = 0.7052
# ~~~~~~~~
# Results:
# 0.780
# 0.604
# 0.732
# 0.705
# ~~~~~~~~
#
# --------------------------------------------------------------
# Results computed with the **unofficial** Python eval code.
# Results should be very close to the official MATLAB eval code.
# Recompute with `./tools/reval.py --matlab ...` for your paper.
# -- Thanks, The Management
# --------------------------------------------------------------
# mAP =  0.7052094212360241
# Loading resume network /home/buaab622/project/PytorchSSD-dota/weights/DOTAweights/RFB_vgg_DOTA_300/2019-06-11-03:11/RFB_vgg_DOTA_epoches_220.pth
# im_detect: 1/1863 0.010s 0.000s
# im_detect: 201/1863 0.009s 0.000s
# im_detect: 401/1863 0.010s 0.000s
# im_detect: 601/1863 0.009s 0.000s
# im_detect: 801/1863 0.009s 0.000s
# im_detect: 1001/1863 0.009s 0.000s
# im_detect: 1201/1863 0.010s 0.000s
# im_detect: 1401/1863 0.009s 0.000s
# im_detect: 1601/1863 0.009s 0.000s
# im_detect: 1801/1863 0.009s 0.000s
# Evaluating detections
# Writing harbor VOC results file
# Writing soccer-ball-field VOC results file
# Writing basketball-court VOC results file
# VOC07 metric? Yes
# AP for harbor = 0.7809
# AP for soccer-ball-field = 0.6007
# AP for basketball-court = 0.7323
# Mean AP = 0.7046
# ~~~~~~~~
# Results:
# 0.781
# 0.601
# 0.732
# 0.705
# ~~~~~~~~
#
# --------------------------------------------------------------
# Results computed with the **unofficial** Python eval code.
# Results should be very close to the official MATLAB eval code.
# Recompute with `./tools/reval.py --matlab ...` for your paper.
# -- Thanks, The Management
# --------------------------------------------------------------
# mAP =  0.7046326113371245
# Loading resume network /home/buaab622/project/PytorchSSD-dota/weights/DOTAweights/RFB_vgg_DOTA_300/2019-06-11-03:11/RFB_vgg_DOTA_epoches_240.pth
# im_detect: 1/1863 0.010s 0.000s
# im_detect: 201/1863 0.009s 0.000s
# im_detect: 401/1863 0.009s 0.000s
# im_detect: 601/1863 0.009s 0.000s
# im_detect: 801/1863 0.010s 0.000s
# im_detect: 1001/1863 0.009s 0.000s
# im_detect: 1201/1863 0.009s 0.000s
# im_detect: 1401/1863 0.010s 0.000s
# im_detect: 1601/1863 0.009s 0.000s
# im_detect: 1801/1863 0.010s 0.000s
# Evaluating detections
# Writing harbor VOC results file
# Writing soccer-ball-field VOC results file
# Writing basketball-court VOC results file
# VOC07 metric? Yes
# AP for harbor = 0.7799
# AP for soccer-ball-field = 0.6004
# AP for basketball-court = 0.7288
# Mean AP = 0.7030
# ~~~~~~~~
# Results:
# 0.780
# 0.600
# 0.729
# 0.703
# ~~~~~~~~
#
# --------------------------------------------------------------
# Results computed with the **unofficial** Python eval code.
# Results should be very close to the official MATLAB eval code.
# Recompute with `./tools/reval.py --matlab ...` for your paper.
# -- Thanks, The Management
# --------------------------------------------------------------
# mAP =  0.7030339487953129
# Loading resume network /home/buaab622/project/PytorchSSD-dota/weights/DOTAweights/RFB_vgg_DOTA_300/2019-06-11-03:11/RFB_vgg_DOTA_epoches_260.pth
# im_detect: 1/1863 0.010s 0.000s
# im_detect: 201/1863 0.010s 0.000s
# im_detect: 401/1863 0.010s 0.000s
# im_detect: 601/1863 0.009s 0.000s
# im_detect: 801/1863 0.009s 0.000s
# im_detect: 1001/1863 0.010s 0.000s
# im_detect: 1201/1863 0.010s 0.000s
# im_detect: 1401/1863 0.009s 0.000s
# im_detect: 1601/1863 0.009s 0.000s
# im_detect: 1801/1863 0.010s 0.000s
# Evaluating detections
# Writing harbor VOC results file
# Writing soccer-ball-field VOC results file
# Writing basketball-court VOC results file
# VOC07 metric? Yes
# AP for harbor = 0.7802
# AP for soccer-ball-field = 0.6058
# AP for basketball-court = 0.7276
# Mean AP = 0.7045
# ~~~~~~~~
# Results:
# 0.780
# 0.606
# 0.728
# 0.705
# ~~~~~~~~
#
# --------------------------------------------------------------
# Results computed with the **unofficial** Python eval code.
# Results should be very close to the official MATLAB eval code.
# Recompute with `./tools/reval.py --matlab ...` for your paper.
# -- Thanks, The Management
# --------------------------------------------------------------
# mAP =  0.7045354783334221
# Loading resume network /home/buaab622/project/PytorchSSD-dota/weights/DOTAweights/RFB_vgg_DOTA_300/2019-06-11-03:11/RFB_vgg_DOTA_epoches_280.pth
# im_detect: 1/1863 0.054s 0.000s
# im_detect: 201/1863 0.009s 0.000s
# im_detect: 401/1863 0.010s 0.000s
# im_detect: 601/1863 0.009s 0.000s
# im_detect: 801/1863 0.010s 0.000s
# im_detect: 1001/1863 0.009s 0.000s
# im_detect: 1201/1863 0.009s 0.000s
# im_detect: 1401/1863 0.009s 0.000s
# im_detect: 1601/1863 0.010s 0.000s
# im_detect: 1801/1863 0.009s 0.000s
# Evaluating detections
# Writing harbor VOC results file
# Writing soccer-ball-field VOC results file
# Writing basketball-court VOC results file
# VOC07 metric? Yes
# AP for harbor = 0.7793
# AP for soccer-ball-field = 0.6006
# AP for basketball-court = 0.7289
# Mean AP = 0.7030
# ~~~~~~~~
# Results:
# 0.779
# 0.601
# 0.729
# 0.703
# ~~~~~~~~
#
# --------------------------------------------------------------
# Results computed with the **unofficial** Python eval code.
# Results should be very close to the official MATLAB eval code.
# Recompute with `./tools/reval.py --matlab ...` for your paper.
# -- Thanks, The Management
# --------------------------------------------------------------
# mAP =  0.7029610449054099
# Loading resume network /home/buaab622/project/PytorchSSD-dota/weights/DOTAweights/RFB_vgg_DOTA_300/2019-06-11-03:11/RFB_vgg_DOTA_epoches_300.pth
# im_detect: 1/1863 0.010s 0.000s
# im_detect: 201/1863 0.010s 0.000s
# im_detect: 401/1863 0.010s 0.000s
# im_detect: 601/1863 0.010s 0.000s
# im_detect: 801/1863 0.009s 0.000s
# im_detect: 1001/1863 0.009s 0.000s
# im_detect: 1201/1863 0.009s 0.000s
# im_detect: 1401/1863 0.010s 0.000s
# im_detect: 1601/1863 0.009s 0.000s
# im_detect: 1801/1863 0.009s 0.000s
# Evaluating detections
# Writing harbor VOC results file
# Writing soccer-ball-field VOC results file
# Writing basketball-court VOC results file
# VOC07 metric? Yes
# AP for harbor = 0.7809
# AP for soccer-ball-field = 0.6041
# AP for basketball-court = 0.7277
# Mean AP = 0.7043
# ~~~~~~~~
# Results:
# 0.781
# 0.604
# 0.728
# 0.704
# ~~~~~~~~
#
# --------------------------------------------------------------
# Results computed with the **unofficial** Python eval code.
# Results should be very close to the official MATLAB eval code.
# Recompute with `./tools/reval.py --matlab ...` for your paper.
# -- Thanks, The Management
# --------------------------------------------------------------
# mAP =  0.7042575721803334
# Loading resume network /home/buaab622/project/PytorchSSD-dota/weights/DOTAweights/RFB_vgg_DOTA_300/2019-06-11-03:11/RFB_vgg_DOTA_epoches_320.pth
# im_detect: 1/1863 0.010s 0.000s
# im_detect: 201/1863 0.009s 0.000s
# im_detect: 401/1863 0.010s 0.000s
# im_detect: 601/1863 0.009s 0.000s
# im_detect: 801/1863 0.009s 0.000s
# im_detect: 1001/1863 0.010s 0.000s
# im_detect: 1201/1863 0.010s 0.000s
# im_detect: 1401/1863 0.009s 0.000s
# im_detect: 1601/1863 0.009s 0.000s
# im_detect: 1801/1863 0.009s 0.000s
# Evaluating detections
# Writing harbor VOC results file
# Writing soccer-ball-field VOC results file
# Writing basketball-court VOC results file
# VOC07 metric? Yes
# AP for harbor = 0.7798
# AP for soccer-ball-field = 0.6028
# AP for basketball-court = 0.7312
# Mean AP = 0.7046
# ~~~~~~~~
# Results:
# 0.780
# 0.603
# 0.731
# 0.705
# ~~~~~~~~
#
# --------------------------------------------------------------
# Results computed with the **unofficial** Python eval code.
# Results should be very close to the official MATLAB eval code.
# Recompute with `./tools/reval.py --matlab ...` for your paper.
# -- Thanks, The Management
# --------------------------------------------------------------
# mAP =  0.7046002667626982
# Loading resume network /home/buaab622/project/PytorchSSD-dota/weights/DOTAweights/RFB_vgg_DOTA_300/2019-06-11-03:11/RFB_vgg_DOTA_epoches_340.pth
# im_detect: 1/1863 0.010s 0.000s
# im_detect: 201/1863 0.009s 0.000s
# im_detect: 401/1863 0.009s 0.000s
# im_detect: 601/1863 0.009s 0.000s
# im_detect: 801/1863 0.010s 0.000s
# im_detect: 1001/1863 0.009s 0.000s
# im_detect: 1201/1863 0.009s 0.000s
# im_detect: 1401/1863 0.010s 0.000s
# im_detect: 1601/1863 0.010s 0.000s
# im_detect: 1801/1863 0.010s 0.000s
# Evaluating detections
# Writing harbor VOC results file
# Writing soccer-ball-field VOC results file
# Writing basketball-court VOC results file
# VOC07 metric? Yes
# AP for harbor = 0.7796
# AP for soccer-ball-field = 0.5993
# AP for basketball-court = 0.7244
# Mean AP = 0.7011
# ~~~~~~~~
# Results:
# 0.780
# 0.599
# 0.724
# 0.701
# ~~~~~~~~
#
# --------------------------------------------------------------
# Results computed with the **unofficial** Python eval code.
# Results should be very close to the official MATLAB eval code.
# Recompute with `./tools/reval.py --matlab ...` for your paper.
# -- Thanks, The Management
# --------------------------------------------------------------
# mAP =  0.7011071980580702
# Loading resume network /home/buaab622/project/PytorchSSD-dota/weights/DOTAweights/RFB_vgg_DOTA_300/2019-06-11-03:11/RFB_vgg_DOTA_epoches_360.pth
# im_detect: 1/1863 0.010s 0.000s
# im_detect: 201/1863 0.009s 0.000s
# im_detect: 401/1863 0.009s 0.000s
# im_detect: 601/1863 0.010s 0.000s
# im_detect: 801/1863 0.009s 0.000s
# im_detect: 1001/1863 0.009s 0.000s
# im_detect: 1201/1863 0.009s 0.000s
# im_detect: 1401/1863 0.010s 0.000s
# im_detect: 1601/1863 0.009s 0.000s
# im_detect: 1801/1863 0.009s 0.000s
# Evaluating detections
# Writing harbor VOC results file
# Writing soccer-ball-field VOC results file
# Writing basketball-court VOC results file
# VOC07 metric? Yes
# AP for harbor = 0.7795
# AP for soccer-ball-field = 0.6028
# AP for basketball-court = 0.7285
# Mean AP = 0.7036
# ~~~~~~~~
# Results:
# 0.779
# 0.603
# 0.728
# 0.704
# ~~~~~~~~
#
# --------------------------------------------------------------
# Results computed with the **unofficial** Python eval code.
# Results should be very close to the official MATLAB eval code.
# Recompute with `./tools/reval.py --matlab ...` for your paper.
# -- Thanks, The Management
# --------------------------------------------------------------
# mAP =  0.7035682505931554
# Loading resume network /home/buaab622/project/PytorchSSD-dota/weights/DOTAweights/RFB_vgg_DOTA_300/2019-06-11-03:11/RFB_vgg_DOTA_epoches_380.pth
# im_detect: 1/1863 0.010s 0.000s
# im_detect: 201/1863 0.010s 0.000s
# im_detect: 401/1863 0.009s 0.000s
# im_detect: 601/1863 0.009s 0.000s
# im_detect: 801/1863 0.009s 0.000s
# im_detect: 1001/1863 0.010s 0.000s
# im_detect: 1201/1863 0.009s 0.000s
# im_detect: 1401/1863 0.009s 0.000s
# im_detect: 1601/1863 0.010s 0.000s
# im_detect: 1801/1863 0.010s 0.000s
# Evaluating detections
# Writing harbor VOC results file
# Writing soccer-ball-field VOC results file
# Writing basketball-court VOC results file
# VOC07 metric? Yes
# AP for harbor = 0.7801
# AP for soccer-ball-field = 0.6038
# AP for basketball-court = 0.7299
# Mean AP = 0.7046
# ~~~~~~~~
# Results:
# 0.780
# 0.604
# 0.730
# 0.705
# ~~~~~~~~
#
# --------------------------------------------------------------
# Results computed with the **unofficial** Python eval code.
# Results should be very close to the official MATLAB eval code.
# Recompute with `./tools/reval.py --matlab ...` for your paper.
# -- Thanks, The Management
# --------------------------------------------------------------
# mAP =  0.7045987273491227
# Loading resume network /home/buaab622/project/PytorchSSD-dota/weights/DOTAweights/RFB_vgg_DOTA_300/2019-06-11-03:11/RFB_vgg_DOTA_epoches_400.pth
# im_detect: 1/1863 0.010s 0.000s
# im_detect: 201/1863 0.009s 0.000s
# im_detect: 401/1863 0.010s 0.000s
# im_detect: 601/1863 0.009s 0.000s
# im_detect: 801/1863 0.010s 0.000s
# im_detect: 1001/1863 0.009s 0.000s
# im_detect: 1201/1863 0.010s 0.000s
# im_detect: 1401/1863 0.009s 0.000s
# im_detect: 1601/1863 0.010s 0.000s
# im_detect: 1801/1863 0.009s 0.000s
# Evaluating detections
# Writing harbor VOC results file
# Writing soccer-ball-field VOC results file
# Writing basketball-court VOC results file
# VOC07 metric? Yes
# AP for harbor = 0.7792
# AP for soccer-ball-field = 0.5979
# AP for basketball-court = 0.7285
# Mean AP = 0.7019
# ~~~~~~~~
# Results:
# 0.779
# 0.598
# 0.728
# 0.702
# ~~~~~~~~
#
# --------------------------------------------------------------
# Results computed with the **unofficial** Python eval code.
# Results should be very close to the official MATLAB eval code.
# Recompute with `./tools/reval.py --matlab ...` for your paper.
# -- Thanks, The Management
# --------------------------------------------------------------
# mAP =  0.7018662250950184

# %%
for i in range(20,410,20):
    print(i)
# Out:
# 20
# 40
# 60
# 80
# 100
# 120
# 140
# 160
# 180
# 200
# 220
# 240
# 260
# 280
# 300
# 320
# 340
# 360
# 380
# 400
